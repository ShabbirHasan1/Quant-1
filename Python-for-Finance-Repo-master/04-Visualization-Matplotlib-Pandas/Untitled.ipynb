# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
# Functional 
plt.plot(x,y,'r-.')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('My first plot')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')

plt.subplot(1,2,2)
plt.plot(y,x,'b--')

# %%
# Object Oriented Method

fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,'r--')

axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('My Title')
# Out:
# Text(0.5, 1.0, 'My Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'r--')
axes1.set_xlabel('X Label')
axes1.set_ylabel('Y Label')
axes1.set_title('Axes 1 Title')

axes2.plot(y,x,'b.-')
axes2.set_xlabel('X Label')
axes2.set_ylabel('Y Label')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

for current_ax in axes:
    current_ax.plot(x,y)

#axes.plot(x,y)

# %%
fig = plt.figure(figsize = (5,3), dpi = 100)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,'g-.',label = 'y = x**2')
ax.plot(x,x**3,'r--', label = 'y = x**3')

ax.legend(loc=0)

# %%
fig.savefig('MyGraphsav.pdf',dpi= 200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,'green',linewidth = 3, alpha = 0.8, linestyle = '-', label = 'X Squared', marker = 's', markersize = 10, 
        markerfacecolor = 'yellow', markeredgewidth = 3, markeredgecolor = 'brown')

ax.legend(loc = 0)

# %%
fig1 = plt.figure(dpi = 100)

ax1 = fig1.add_axes([0,0,1,1])

ax1.plot(x,x**2,'green',lw = 3,linestyle = '--', label = 'y = X Squared')

#ax1.set_xlim([0,10])
#ax1.set_ylim([0,50])

ax1.legend(loc = 0)
#ax1.grid(True)

ax1.grid(color='r', alpha=1, linestyle='dotted', linewidth=0.8)

ax1.spines['left'].set_color('brown')
ax1.spines['left'].set_linewidth(3)

ax1.spines['right'].set_color('blue')

ax1.set_xlabel('x')
ax1.set_ylabel('y = $x^2$')
ax1.set_title('The Graph of y = $x^2$')

for label in ax1.get_yticklabels():
    label.set_color("orange")
    
ax1.xaxis.set_ticks_position('bottom')
ax1.spines['bottom'].set_position(('data',0)) # set position of x spine to x=0

ax1.yaxis.set_ticks_position('left')
ax1.spines['left'].set_position(('data',0))   # set position of y spine to y=0

#ax1.text('This is the line I wanted')

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)");

# %%
fig, ax = plt.subplots(1, 1)
      
ax.plot(x, x**2, x, np.exp(x))
ax.set_title("scientific notation")

ax.set_yticks([0, 50, 100, 150])

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.yaxis.set_major_formatter(formatter)

# %%
# Out:
# (array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#         20.25, 25.  ]))

# %%
n = np.array([0,1,2,3,4,5])
xx = np.linspace(-0.75, 1., 100)

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes[0].set_title("scatter")

axes[1].step(n, n**2, lw=2)
axes[1].set_title("step")

axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes[2].set_title("bar")

axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[3].set_title("fill_between");
